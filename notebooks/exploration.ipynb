# %% [markdown]
# # Geometric Figures — Exploration
# Visualise generated images, inspect class distributions, and sanity-check preprocessing.

# %%
import sys
sys.path.insert(0, '../src')

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1. Generate Sample Images

# %%
# TODO: call generate_triangle / generate_circle and display results

# %% [markdown]
# ## 2. Inspect Preprocessed Data

# %%
# TODO: load a batch from GeometricDataset and visualise tensors

# %% [markdown]
# ## 3. Class Distribution

# %%
# TODO: plot bar chart of train / val / test class counts

# %% [markdown]
# ## 4. Training Curves

# %%
# TODO: load training logs and plot loss / accuracy curves
